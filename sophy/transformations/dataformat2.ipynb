# %%
import os
import pandas as pd
import numpy as np
import sqlite3
import cartopy.crs as ccrs
import geopandas as gpd
from geopandas import GeoDataFrame
from pandas import DataFrame, Series, Index

# %%
w1 = pd.ExcelWriter('data/in/datasets/lter2022.xlsx', engine="openpyxl", mode='a')
cruise = pd.read_excel("data/in/datasets/lter2022.xlsx", sheet_name=0)
station = pd.read_excel("data/in/datasets/lter2022.xlsx", sheet_name=1)
# Out:
# C:\Users\Ayush Nag\AppData\Local\Temp\ipykernel_16916\4125163947.py:2: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   cruise = pd.read_excel("data/in/datasets/lter2022.xlsx", sheet_name=0)
# C:\Users\Ayush Nag\AppData\Local\Temp\ipykernel_16916\4125163947.py:3: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   station = pd.read_excel("data/in/datasets/lter2022.xlsx", sheet_name=1)

# %%
# set(station.columns) - set(cruise.columns)
len(set(station.columns).union(set(cruise.columns)))
# Out:
# 90

# %%
merged = pd.concat([cruise, station], axis=0, ignore_index=True)

# %%
merged
# Out:
#       studyName         DatetimeGMT  JulianDay  Event  GridLine  GridStation  \
# 0       PD91-09 1991-11-07 00:36:00      311.0    1.0     619.0         35.0
# 1       PD91-09 1991-11-07 00:36:00      311.0    1.0     619.0         35.0
# 2       PD91-09 1991-11-07 00:36:00      311.0    1.0     619.0         35.0
# 3       PD91-09 1991-11-07 00:36:00      311.0    1.0     619.0         35.0
# 4       PD91-09 1991-11-07 00:36:00      311.0    1.0     619.0         35.0
# ...         ...                 ...        ...    ...       ...          ...
# 49735   PAL2021 2021-05-04 00:00:00      124.0   54.0       NaN          NaN
# 49736   PAL2021 2021-05-04 00:00:00      124.0   54.0       NaN          NaN
# 49737   PAL2021 2021-05-04 00:00:00      124.0   54.0       NaN          NaN
# 49738   PAL2021 2021-05-04 00:00:00      124.0   54.0       NaN          NaN
# 49739   PAL2021 2021-05-04 00:00:00      124.0   54.0       NaN          NaN
#
# ...

# %%
merged.to_excel(w1, sheet_name="sophy_sample", index=False)
# Out:
# C:\Users\Ayush Nag\AppData\Local\Temp\ipykernel_16916\1875138262.py:2: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   w1.save()

# %% [markdown]
# ## Alderkamp

# %%
cruise = pd.read_excel("data/in/datasets/lter2022.xlsx", sheet_name=0)
station = pd.read_excel("data/in/datasets/lter2022.xlsx", sheet_name=1)
