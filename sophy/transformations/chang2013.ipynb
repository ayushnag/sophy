# %%
import pandas as pd

# %%
chang = pd.read_csv('../../data/datasets/unmodified/chang2013/chang_table1.csv')
species_comp = pd.read_csv('../../data/datasets/unmodified/chang2013/chang_table2.csv', encoding='cp1252')
microscopy = pd.read_csv('../../data/datasets/unmodified/chang2013/chang_table3.csv', encoding='cp1252')

# %%
microscopy
# Out:
#                                 TAXA  Ross Ice Shelf Less than 0.1  \
# 0                            Centric             NaN           NaN
# 1    Asteromphalus hookeri Ehrenberg             1.0           NaN
# 2       Asteromphalus hyalinus Karst             0.3           NaN
# 3       Asteromphalus parvulus Karst             0.7           NaN
# 4   Chaetoceros concavicornis Mangin             0.1             <
# ..                               ...             ...           ...
# 80            Class Prymnesiophyceae             NaN           NaN
# 81      Phaeocystis antarctica Karst           290.0           NaN
# 82              Class Prasinophyceae             NaN           NaN
# 83                  Pyramimonas spp.             0.1           NaN
# 84                  Monads (unknown)             9.3           NaN
#
#     Antarctic Slope Less than 0.1.1 Offshore South of PF Less than 0.1.2  \
# 0               NaN             NaN                  NaN             NaN
# ...

# %%
chang
# Out:
#    Station  Latitude  Temp  Salinity  Nitrate (NO3)  Ammonium  \
# 0       C1     74.59 -0.79     34.20          14.29      0.29
# 1       C2     77.75 -1.50     33.85          22.00      0.10
# 2       C3     75.62 -0.78     34.28          22.86      0.36
# 3       C4     76.18 -1.57     33.98          22.64      0.86
# 4      C15     75.29 -1.69     33.87          30.86      1.36
# 5      C16     72.32 -1.77     33.93          25.93      2.00
# 6      C17     72.09 -1.70     34.07          26.57      0.43
# 7      C18     71.38 -1.62     34.04          28.21      0.36
# 8      C25     72.08 -1.65     34.03          29.29      0.57
# 9      C26     72.02 -1.49     33.76          21.21      0.57
# 10     C27     71.93 -1.48     34.21          25.14      0.21
# 11     C24     66.98 -1.42     33.79          27.64      0.36
# 12     C29     69.42 -1.82     32.61          27.43      0.50
# 13     C30     68.52 -1.77     33.65          27.71      0.50
# ...

# %%
species_comp
# Out:
#                                   Station  Position (Lat.)  Temp.  Salinity  \
# 0                  Ross Sea shelf (>73 S)              NaN    NaN       NaN
# 1                                    P637            76.70  -1.83     33.97
# 2                                    P638            76.60  -1.70     34.19
# 3                                    P636            76.56  -1.09     34.33
# 4                                    P640            76.51  -1.39     34.32
# 5                                    P633            75.65  -1.19     34.17
# 6                                    P632            75.08  -1.47     33.98
# 7                                    P641            74.76  -1.09     34.03
# 8                                    P644            72.50  -1.34     34.13
# 9                       Slope (70 S–73 S)              NaN    NaN       NaN
# 10                                   P625            71.74  -1.15     33.98
# ...

# %%
# Steps
# TODO: How to correlate the C Stations with the P stations
# TODO: What to do with only dinoflagellates
